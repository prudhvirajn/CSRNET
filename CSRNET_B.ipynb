# %% [markdown]
# <a href="https://colab.research.google.com/github/prudhvirajn/CSRNET/blob/master/CSRNET_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

tf.keras.backend.clear_session()
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
def generate_model()
  img_inputs = keras.Input(shape=(None,None,3), name='img')

  x = layers.Conv2D(64, 3, activation='relu', padding='same')(img_inputs)
  x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
  x = layers.MaxPooling2D(strides=2)(x)

  x = layers.Conv2D(128, 3, activation='relu', padding='same')(x)
  x = layers.Conv2D(128, 3, activation='relu', padding='same')(x)
  x = layers.MaxPooling2D(strides=2)(x)

  x = layers.Conv2D(256, 3, activation='relu', padding='same')(x)
  x = layers.Conv2D(256, 3, activation='relu', padding='same')(x)
  x = layers.Conv2D(256, 3, activation='relu', padding='same')(x)
  x = layers.MaxPooling2D(strides=2)(x)

  x = layers.Conv2D(512, 3, activation='relu', padding='same')(x)
  x = layers.Conv2D(512, 3, activation='relu', padding='same')(x)
  x = layers.Conv2D(512, 3, activation='relu', padding='same')(x)

  x = layers.Conv2D(512, 3, activation='relu', padding='same', dilation_rate=2)(x)
  x = layers.Conv2D(512, 3, activation='relu', padding='same', dilation_rate=2)(x)
  x = layers.Conv2D(512, 3, activation='relu', padding='same', dilation_rate=2)(x)

  x = layers.Conv2D(256, 3, activation='relu', padding='same', dilation_rate=2)(x)
  x = layers.Conv2D(128, 3, activation='relu', padding='same', dilation_rate=2)(x)
  x = layers.Conv2D(64, 3, activation='relu', padding='same', dilation_rate=2)(x)
  output = layers.Conv2D(1, 1, activation='relu', padding='same', name='output')(x)
  
  return (img_inputs, output)

# %%
model = keras.Model(inputs=img_inputs, outputs=output, name='csrnet_b')

# %%
model.summary()
# Out:
# Model: "csrnet_b"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# img (InputLayer)             [(None, None, None, 3)]   0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, None, None, 64)    1792
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, None, None, 64)    36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, None, None, 64)    0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, None, None, 128)   73856
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, None, None, 128)   147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, None, None, 128)   0
# ...

# %%
keras.utils.plot_model(model, 'my_first_model.png')
